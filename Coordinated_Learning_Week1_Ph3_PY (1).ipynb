# %% [markdown]
# <font size=6 bold=true>Dec 15 </font>
# ## Parse One Page. And Logics to parse a full website
# ## Make sure of libraries
# ## Review Python variables and data structures
# ## Brainstorm: define a data structure to store (implementation next lesson)

# %%
#import selenius
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urlparse

# %%
need_tag_list=['a', 
     'body',   
     'div',
     'h1',
     'h2',
     'h3',
     'h4',
     'h5',
     'head',
     'header',
     'label',
     'li',
     'meta',
     'p',
     'script',
     'span',
     'strong',
     'textarea',
     'title',
     'ul']
#s=set([re.sub(r'[_+!@#$?\\/^]+$', '', item) for item in strings])
base_url="https://www.washington.edu/"
base_domain='www.wellesley.edu'
#base_url="https://www.stempro.org"
#base_domain='www.stempro.org'
base_url=re.sub(r'[_+!@#$?\\\s]+$', '', base_url)
base_url=re.sub(r'[/\s]$','', base_url) 

def all_pages(base_url, links_only=True):
    response=requests.get(base_url)
    unique_urls={base_url}
    visited_urls=set()
    unables=set()
    while len(unique_urls)>len(visited_urls):
        soup=BeautifulSoup(response.text, 'html.parser')
        for link in soup.find_all('a'):
            try:
                url=link['href']                
                parsed_uri = urlparse(url )
                if parsed_uri.netloc=='':
                    absolute_url=base_url+url    
                elif parsed_uri.netloc==base_domain:
                    absolute_url=url
                else:
                    continue
                    #netname = '{uri.scheme}://{uri.netloc}/'.format(uri=parsed_uri) 
               ##
                clean=re.sub(r'[_+!@#$?\\\s]+$', '', absolute_url)
                clean=''.join(clean[0:10])+(''.join(clean[11:])).replace('//', '/')
                clean=re.sub(r'[/\s]$','', clean)
                unique_urls.add(clean)
                #unique_urls.add(re.sub(r'[_+!@#$?\\/^\s]+$', '', absolute_url))                  
            except:
                continue            
        unvisited_url=(unique_urls-visited_urls-unables).pop()
        visited_urls.add(unvisited_url)
        response=requests.get(unvisited_url)
        if links_only!=True and response.status_code=='200': #use a different routine to get text data from resonse. 
            handleOnePage(unvisited_url)
        else:
            unables.add(unvisited_url)  
    return unique_urls
  
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title'] and re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
   
    return True

# %%
def handleOnePage(unvisited_url):
    #resonse = requests.get("https://stackoverflow.com/questions/29283510/what-is-the-difference-beautifulsoup-and-bs4")
    resonse = requests.get(unvisited_url) 
    soup = BeautifulSoup(resonse.content, "html.parser")
    in_the_page=set([tag.name for tag in soup.find_all()]) 
 
    go_throug=in_the_page.intersection(need_tag_list) 
   
    for tag in go_throug:   
        
       for one_by_one in soup.find_all(tag): 
            data1=one_by_one.findAll(text=True)
            r1=filter(visible, data1)
            textcontent=[i for i in r1 if len(i)>2]   
            print(textcontent)

# %%
url=input("college:" )
handleOnePage(url)
# Out:
# college:https://www.wellesley.edu/academics/theacademicprogram
# ['Search']
# ['About', 'Mission & Values', 'Robust Financial Aid', 'Wellesley Facts', 'Accreditation', 'Strategic Planning', 'President', 'The Wellesley Effect', 'The Campus', 'Sustainability', 'Wellesley in The World', 'College History', 'Wellesley Blogs', 'Visit']
# ['Mission & Values']
# ['Robust Financial Aid']
# ['Wellesley Facts']
# ['Accreditation']
# ['Strategic Planning']
# ['President']
# ['The Wellesley Effect']
# ['The Campus']
# ['Sustainability']
# ['Wellesley in The World']
# ['College History']
# ['Wellesley Blogs']
# ['Visit']
# ['Admission & Financial Aid', 'Apply', 'Visit', 'Cost & Financial Aid', 'Diversity & Inclusion', 'Why Wellesley?', 'FAQ', 'Contact Us']
# ['Apply']
# ['Visit']
# ['Cost & Financial Aid']
# ['Diversity & Inclusion']
# ['Why Wellesley?']
# ['FAQ']
# ['Contact Us']
# ['Academics', 'The Academic Program', 'Library & Technology', 'Departments, Programs, & Majors', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['The Academic Program']
# ['Library & Technology']
# ['Departments, Programs, & Majors']
# ['Course Catalog']
# ['WellesleyX']
# ['Faculty']
# ['Academic Centers']
# ['Academic Institutes']
# ['Academic Advising & Support']
# ['Registrar']
# ['Academic Summer Programs']
# ['Campus Life', 'Housing', 'Dining', 'Our Community', 'Health and Wellness', 'Getting to Boston', 'Student Life', 'Career Education']
# ['Housing']
# ['Dining']
# ['Our Community']
# ['Health and Wellness']
# ['Getting to Boston']
# ['Student Life']
# ['Career Education']
# ['Athletics', 'Physical Education', 'Athletics', 'Recreation', 'Facilities & Hours']
# ['Physical Education']
# ['Athletics']
# ['Recreation']
# ['Facilities & Hours']
# ['News', '2019 Stories', 'Wellesley in the News', 'Press Room', 'Daily Shot Gallery', 'News Archive']
# ['2019 Stories']
# ['Wellesley in the News']
# ['Press Room']
# ['Daily Shot Gallery']
# ['News Archive']
# ['Events', 'The Arts at Wellesley', 'Wellesley on iTunes', 'Calendar', 'Event Planning', 'Commencement']
# ['The Arts at Wellesley']
# ['Wellesley on iTunes']
# ['Calendar']
# ['Event Planning']
# ['Commencement']
# ['Administration', 'Committees & Groups', 'Offices', 'Policies', 'Working at Wellesley']
# ['Committees & Groups']
# ['Offices']
# ['Policies']
# ['Working at Wellesley']
# ['Alumnae', 'Alumnae in the News', 'Online Community', 'Classes, Clubs, & Groups', 'Events & Reunion', 'Wellesley Magazine', 'Awards', 'Volunteer', 'Life-Long Learning', 'Giving to Wellesley', 'About the Association']
# ['Alumnae in the News']
# ['Online Community']
# ['Classes, Clubs, & Groups']
# ['Events & Reunion']
# ['Wellesley Magazine']
# ['Awards']
# ['Volunteer']
# ['Life-Long Learning']
# ['Giving to Wellesley']
# ['About the Association']
# ['Academics']
# ['The Academic Program']
# []
# []
# []
# []
# []
# ['International study', '—approximately half of our students study abroad at some point during their time at Wellesley.']
# ['Research opportunities—our students work closely with professors on meaningful, challenging projects.']
# ['Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.']
# ['Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.']
# ['Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.']
# ['Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar']
# ['Degree Requirements']
# ['International Study']
# ['Davis Degree Program']
# ['Opportunities at Other Schools']
# ['Postbaccalaureate']
# ['Calderwood Seminars in Public Writing']
# ['First Year Seminar']
# ['Library & Technology']
# ['Departments, Majors & Programs']
# ['Course Catalog']
# ['WellesleyX']
# ['Faculty']
# ['Academic Centers']
# ['Academic Institutes']
# ['Academic Advising & Support']
# ['Registrar']
# ['Academic Summer Programs']
# ['Provost & Dean of the College']
# ['The Humanities']
# ['Ruhlman Conference']
# ['Three College Collaboration']
# ['Health Professions Advising']
# ['Working at Wellesley']
# ['Giving to Wellesley']
# ['Directory']
# ['Terms of Use']
# ['Privacy']
# ['Key Facts']
# ['Web Accessibility']
# ['Feedback']
# ['Webmaster']
# ['2/3']
# ['Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.']
# ['Ruhlman Conference']
# []
# ['Wellesley in Washington']
# ['The Academic Program']
# ['Skip to main content']
# []
# [' MyWellesley', 'Give', ' .btn-navbar is used as the toggle for collapsed navbar content ', 'Toggle navigation', ' search for desktops ', ' dropdown search for tablet & mobile ', 'Search', '/.navbar-header', 'About', 'Mission & Values', 'Robust Financial Aid', 'Wellesley Facts', 'Accreditation', 'Strategic Planning', 'President', 'The Wellesley Effect', 'The Campus', 'Sustainability', 'Wellesley in The World', 'College History', 'Wellesley Blogs', 'Visit', 'Admission & Financial Aid', 'Apply', 'Visit', 'Cost & Financial Aid', 'Diversity & Inclusion', 'Why Wellesley?', 'FAQ', 'Contact Us', 'Academics', 'The Academic Program', 'Library & Technology', 'Departments, Programs, & Majors', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Campus Life', 'Housing', 'Dining', 'Our Community', 'Health and Wellness', 'Getting to Boston', 'Student Life', 'Career Education', 'Athletics', 'Physical Education', 'Athletics', 'Recreation', 'Facilities & Hours', 'News', '2019 Stories', 'Wellesley in the News', 'Press Room', 'Daily Shot Gallery', 'News Archive', 'Events', 'The Arts at Wellesley', 'Wellesley on iTunes', 'Calendar', 'Event Planning', 'Commencement', 'Administration', 'Committees & Groups', 'Offices', 'Policies', 'Working at Wellesley', 'Alumnae', 'Alumnae in the News', 'Online Community', 'Classes, Clubs, & Groups', 'Events & Reunion', 'Wellesley Magazine', 'Awards', 'Volunteer', 'Life-Long Learning', 'Giving to Wellesley', 'About the Association', '/.navbar-collapse']
# [' MyWellesley', 'Give', ' .btn-navbar is used as the toggle for collapsed navbar content ', 'Toggle navigation', ' search for desktops ', ' dropdown search for tablet & mobile ', 'Search']
# []
# ['About', 'Mission & Values', 'Robust Financial Aid', 'Wellesley Facts', 'Accreditation', 'Strategic Planning', 'President', 'The Wellesley Effect', 'The Campus', 'Sustainability', 'Wellesley in The World', 'College History', 'Wellesley Blogs', 'Visit', 'Admission & Financial Aid', 'Apply', 'Visit', 'Cost & Financial Aid', 'Diversity & Inclusion', 'Why Wellesley?', 'FAQ', 'Contact Us', 'Academics', 'The Academic Program', 'Library & Technology', 'Departments, Programs, & Majors', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Campus Life', 'Housing', 'Dining', 'Our Community', 'Health and Wellness', 'Getting to Boston', 'Student Life', 'Career Education', 'Athletics', 'Physical Education', 'Athletics', 'Recreation', 'Facilities & Hours', 'News', '2019 Stories', 'Wellesley in the News', 'Press Room', 'Daily Shot Gallery', 'News Archive', 'Events', 'The Arts at Wellesley', 'Wellesley on iTunes', 'Calendar', 'Event Planning', 'Commencement', 'Administration', 'Committees & Groups', 'Offices', 'Policies', 'Working at Wellesley', 'Alumnae', 'Alumnae in the News', 'Online Community', 'Classes, Clubs, & Groups', 'Events & Reunion', 'Wellesley Magazine', 'Awards', 'Volunteer', 'Life-Long Learning', 'Giving to Wellesley', 'About the Association']
# ['Academics', 'The Academic Program', ' if no right sidebar, middle section is 10 cols, else 8 cols ', 'The Academic Program', '\n  .carousel {\n    padding-bottom: 35px;\n  }\n  .carousel-indicators {\n    bottom: -35px;\n    padding-bottom: 24px;\n  }\n  .carousel-indicators li {\n    border: 2px solid #101778;\n    background-color: #fff;\n  }\n  .carousel-indicators .active {\n    background-color: #101778;\n  }\n  .carousel-caption {\n    display: block;\n    text-align: left;\n    width: 100%;\n    height: auto;\n    background-color: rgba(16, 23, 120, 0.9);\n    left: 0;\n    bottom: 0;\n    padding: 10px;\n  }\n  .carousel-caption a {\n    color: #218bc1 !important;\n  }\n\n\n', ' .carousel-inner ', 'Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.', 'Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising', '2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.', '/.col-md-12', '/.row']
# ['Academics', 'The Academic Program']
# [' if no right sidebar, middle section is 10 cols, else 8 cols ', 'The Academic Program', '\n  .carousel {\n    padding-bottom: 35px;\n  }\n  .carousel-indicators {\n    bottom: -35px;\n    padding-bottom: 24px;\n  }\n  .carousel-indicators li {\n    border: 2px solid #101778;\n    background-color: #fff;\n  }\n  .carousel-indicators .active {\n    background-color: #101778;\n  }\n  .carousel-caption {\n    display: block;\n    text-align: left;\n    width: 100%;\n    height: auto;\n    background-color: rgba(16, 23, 120, 0.9);\n    left: 0;\n    bottom: 0;\n    padding: 10px;\n  }\n  .carousel-caption a {\n    color: #218bc1 !important;\n  }\n\n\n', ' .carousel-inner ', 'Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.', 'Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising', '2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.', '/.col-md-12']
# [' if no right sidebar, middle section is 10 cols, else 8 cols ', 'The Academic Program', '\n  .carousel {\n    padding-bottom: 35px;\n  }\n  .carousel-indicators {\n    bottom: -35px;\n    padding-bottom: 24px;\n  }\n  .carousel-indicators li {\n    border: 2px solid #101778;\n    background-color: #fff;\n  }\n  .carousel-indicators .active {\n    background-color: #101778;\n  }\n  .carousel-caption {\n    display: block;\n    text-align: left;\n    width: 100%;\n    height: auto;\n    background-color: rgba(16, 23, 120, 0.9);\n    left: 0;\n    bottom: 0;\n    padding: 10px;\n  }\n  .carousel-caption a {\n    color: #218bc1 !important;\n  }\n\n\n', ' .carousel-inner ', 'Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.', 'Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising', '2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['\n  .carousel {\n    padding-bottom: 35px;\n  }\n  .carousel-indicators {\n    bottom: -35px;\n    padding-bottom: 24px;\n  }\n  .carousel-indicators li {\n    border: 2px solid #101778;\n    background-color: #fff;\n  }\n  .carousel-indicators .active {\n    background-color: #101778;\n  }\n  .carousel-caption {\n    display: block;\n    text-align: left;\n    width: 100%;\n    height: auto;\n    background-color: rgba(16, 23, 120, 0.9);\n    left: 0;\n    bottom: 0;\n    padding: 10px;\n  }\n  .carousel-caption a {\n    color: #218bc1 !important;\n  }\n\n\n', ' .carousel-inner ', 'Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# ['\n  .carousel {\n    padding-bottom: 35px;\n  }\n  .carousel-indicators {\n    bottom: -35px;\n    padding-bottom: 24px;\n  }\n  .carousel-indicators li {\n    border: 2px solid #101778;\n    background-color: #fff;\n  }\n  .carousel-indicators .active {\n    background-color: #101778;\n  }\n  .carousel-caption {\n    display: block;\n    text-align: left;\n    width: 100%;\n    height: auto;\n    background-color: rgba(16, 23, 120, 0.9);\n    left: 0;\n    bottom: 0;\n    padding: 10px;\n  }\n  .carousel-caption a {\n    color: #218bc1 !important;\n  }\n\n\n', ' .carousel-inner ', 'Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# []
# [' .carousel-inner ']
# []
# []
# []
# []
# []
# []
# []
# ['Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# []
# ['Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# ['Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# ['Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# ['Wellesley’s rigorous and dynamic academic program allows each student to pursue a course of study that’s right for her.', 'Wellesley requires each student to acquire a broad knowledge of the basic fields of human inquiry, while also enabling her to follow her own particular interests in depth. Our core curriculum is strategically designed to deliver on Wellesley’s rigorous academic and educational goals.', 'In addition to the core curriculum, Wellesley offers an impressive variety of educational opportunities. A high percentage of our students participate in one or more of these choices, making them an important part of the overall Wellesley academic experience. These include:', 'International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.', 'A degree from Wellesley College demonstrates that a student has constructed a broad intellectual foundation, as well as pursued a passionate interest to admirable accomplishment. Perhaps that is why a Wellesley education is highly prized among graduate schools and employers alike.']
# []
# []
# []
# []
# ['Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising', '2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Links', 'Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# []
# []
# []
# []
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# []
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.', 'Ruhlman Conference', 'Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.', 'Wellesley in Washington', 'Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# ['2/3', 'Two out of three female U.S. Secretaries of State have been Wellesley grads.']
# ['Students present their work across academic disciplines in a community celebration of student achievement. Performances, readings, panels, and presentations fill an entire day each spring.']
# ['Interested in government? Learn about it firsthand in government offices, political and public interest groups, media, or research and cultural institutions. Housing and a stipend are provided.']
# []
# []
# []
# []
# ['Working at Wellesley', 'Giving to Wellesley', 'Directory', 'Terms of Use', 'Privacy', 'Key Facts', 'Web Accessibility', 'Feedback', 'Webmaster']
# ['Working at Wellesley', 'Giving to Wellesley', 'Directory', 'Terms of Use', 'Privacy', 'Key Facts', 'Web Accessibility', 'Feedback', 'Webmaster']
# ['\n              Copyright © Trustees of Wellesley College \xa0\xa0| \xa0\xa0Wellesley College 106 Central Street – Wellesley, MA 02481 (781) 283-1000\n          ']
# ['\n              Copyright © Trustees of Wellesley College \xa0\xa0| \xa0\xa0Wellesley College 106 Central Street – Wellesley, MA 02481 (781) 283-1000\n          ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ', 'mobile closed', '\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ', 'mobile opened ', '<div id="mobile-max" class="hidden-lg hidden-md hidden-sm col-xs-12" style="display:none">']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# ['\r\n      .logocolor {\r\n        fill: #fff;\r\n      }\r\n      .logocolor:hover {\r\n        fill: #fff;\r\n      }\r\n  ']
# []
# []
# ['The Academic Program | Wellesley College', ' HTML5 element support for IE6-8 ', '[if lt IE 9]>\n    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n  <![endif]', 'window.jQuery || document.write("<script src=\'/sites/all/modules/jquery_update/replace/jquery/1.7/jquery.min.js\'>\\x3C/script>")', '(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-6658128-21", {"cookieDomain":"auto"});ga(\'create\', \'UA-6658128-13\', \'auto\', {\'name\': \'newTracker\'});ga("set", "page", location.pathname + location.search + location.hash);ga("send", "pageview");ga(\'newTracker.send\', \'pageview\');', 'jQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"w_bootstrap_subtheme","theme_token":"BMP-QHxkZaRzrxeJm9iI_qs6ksHm8L0BC9f93B8zm6M","css":{"modules\\/system\\/system.base.css":1,"sites\\/all\\/modules\\/contrib\\/calendar\\/css\\/calendar_multiday.css":1,"sites\\/all\\/modules\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"sites\\/all\\/modules\\/date\\/date_repeat_field\\/date_repeat_field.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"sites\\/all\\/modules\\/video_filter\\/video_filter.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"sites\\/all\\/modules\\/thickbox\\/thickbox.css":1,"sites\\/all\\/modules\\/bootstrap_carousel\\/styles\\/bootstrap_carousel.css":1,"sites\\/all\\/libraries\\/fontawesome\\/css\\/font-awesome.css":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.0.2\\/css\\/bootstrap.min.css":1,"sites\\/all\\/themes\\/bootstrap\\/css\\/3.0.2\\/overrides.min.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/css\\/global_style.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/css\\/style.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/css\\/homepage.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/css\\/print.css":1},"js":{"sites\\/all\\/themes\\/bootstrap\\/js\\/bootstrap.js":1,"\\/\\/ajax.googleapis.com\\/ajax\\/libs\\/jquery\\/1.7.2\\/jquery.min.js":1,"0":1,"misc\\/jquery-extend-3.4.0.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.0.2\\/js\\/bootstrap.min.js":1,"sites\\/all\\/modules\\/thickbox\\/thickbox.js":1,"https:\\/\\/www.youtube.com\\/player_api":1,"sites\\/all\\/modules\\/bootstrap_carousel\\/scripts\\/bootstrap_carousel.js":1,"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js":1,"1":1,"sites\\/all\\/libraries\\/jquery.migrate\\/jquery-migrate-1.2.1.min.js":1,"sites\\/all\\/themes\\/bootstrap\\/js\\/main.js":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/..\\/..\\/libraries\\/masonry\\/jquery.masonry.min.js":1}},"thickbox":{"close":"Close","next":"Next \\u003E","prev":"\\u003C Prev","esc_key":"or Esc Key","next_close":"Next \\/ Close on last","image_count":"Image !current of !total"},"bootstrap_carousel":{"interval":"5000","pause":""},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackColorbox":1,"trackUrlFragments":1},"bootstrap":{"anchorsFix":1,"anchorsSmoothScrolling":1,"formHasError":1,"popoverEnabled":1,"popoverOptions":{"animation":1,"html":0,"placement":"right","selector":"","trigger":"click hover focus manual","triggerAutoclose":1,"title":"","content": ...
# ...
# []
# []
# ['\n        // RR - 03/15/2012 Added Get_Cookie and Set_Cookie functions\n\t\t// this function gets the cookie, if it exists\n\t\t// don\'t use this, it\'s weak and does not handle some cases\n\t\t// correctly, this is just to maintain legacy information\n\n\t\t\tfunction Get_Cookie( name )\n\t\t\t{\n\t\t\t\tvar start = document.cookie.indexOf( name + "=" );\n\t\t\t  \tvar len = start + name.length + 1;\n\t\t\t  \tif ( ( !start ) &&\n\t\t\t\t\t( name != document.cookie.substring( 0, name.length ) ) )\n\t\t\t\t{\n\t\t\t\t  \treturn null;\n\t\t\t\t}\n\t\t\t  \tif ( start == -1 ) return null;\n\t\t\t  \tvar end = document.cookie.indexOf( ";", len );\n\t\t\t  \tif ( end == -1 ) end = document.cookie.length;\n\t\t\t  \treturn unescape( document.cookie.substring( len, end ) );\n\t\t\t}\n\n\t\t\tfunction Set_Cookie( name, value, expires, path, domain, secure )\n\t\t\t{\n\t\t\t  \t// set time, it\'s in milliseconds\n\t\t\t  \tvar today = new Date();\n\t\t\t  \ttoday.setTime( today.getTime() );\n\n\t\t\t\t/* if the expires variable is set, make the correct\n\t\t\t\texpires time, the current script below will set\n\t\t\t\tit for x number of days, to make it for hours,\n\t\t\t\tdelete * 24, for minutes, delete * 60 * 24\n\t\t\t\t*/\n\t\t\t  \tif ( expires )\n\t\t\t\t{\n\t\t\t\t  expires = expires * 1000 * 60 * 60 * 24;\n\t\t\t\t}\n\t\t\t  var expires_date = new Date( today.getTime() + (expires) );\n\n\t\t\t  document.cookie = name + "=" +escape( value ) +\n\t\t\t\t( ( expires ) ? ";expires=" + expires_date.toGMTString() : "" ) +\n\t\t\t\t( ( path ) ? ";path=" + path : "" ) +\n\t\t\t\t( ( domain ) ? ";domain=" + domain : "" ) +\n\t\t\t\t( ( secure ) ? ";secure" : "" );\n\t\t\t}\n\n\t\t']
# ["\n\n\t\t\t// on load check if the cookie for wellesley_menu is off\n\n\t\t\tvar cookie_value = Get_Cookie('wellesley_menu');\n\n\t\t\tif (cookie_value == 'off' || cookie_value === null) {\n\t\t\t\t//closed\n\t\t\t\tvar div = document.getElementById('fixed-menu-min');\n\t\t\t\tdiv.style.display = 'block';\n\t\t\t\tvar div = document.getElementById('fixed-menu-max');\n\t\t\t\t// div.style.display = 'none';\n\n\t\t\t\t//opened - DISABLED FOR ACCESSIBILITY\n\t\t\t } else {\n\t\t\t  \tvar div = document.getElementById('fixed-menu-max');\n\t\t\t  \t// div.style.display = 'block';\n\t\t\t  \tvar div = document.getElementById('fixed-menu-min');\n\t\t\t  \t// div.style.display = 'none';\n          div.style.display = 'block'\n\t\t\t }\n\n\n\t\t"]
# ['\n\n       \t\t//click to maximize menu - DISABLED FOR ACCESSIBILITY\n\n           //  (function ($) {$("#fixed-menu-min").click(function () {\n           //  \t$("#fixed-menu-max").slideToggle("normal");\n           //     \t$("#fixed-menu-min").fadeToggle("fast", "linear");\n\n           // // add wellesley_menu cookie\n\n           // Set_Cookie("wellesley_menu","on","",\'/\',\'\',\'\');\n           //  });})(jQuery);\n\n\t\t\t//click hide button to minimize menu\n\n            (function ($) {$(".hide_menu").click(function () {\n              \t$("#fixed-menu-max").fadeToggle("fast","linear");\n             \t$("#fixed-menu-min").slideToggle("normal");\n\n           // add wellesley_menu cookie - turn off\n          \tSet_Cookie("wellesley_menu","off","",\'/\',\'\',\'\');\n            });})(jQuery);\n\n\n  \t\t\t(function ($) {$(".hide_mobile").click(function () {\n              \t$("#mobile-max").fadeToggle("fast","linear");\n             \t$("#mobile-min").slideToggle("normal");\n\n            });})(jQuery);\n            // DISABLED FOR ACCESSIBILITY\n          // (function ($) {$("#mobile-min").click(function () {\n          //   \t$("#mobile-max").slideToggle("normal");\n          //      \t$("#mobile-min").fadeToggle("fast", "linear");\n\n\n          //   });})(jQuery);\n\n\n\n\t\t<!--TOGGLE SCRIPT-->\n\t\t(function ($){$(\'.reveal\').hide();\n\t\t \t$(\'.toggle\').click(function(){\n\t\t  \tvar t = $(this);\n\t\t  \tt.parent().find(\'.reveal\').toggle("fast");\n\t\t })})(jQuery);\n\t    <!--END TOGGLE SCRIPT-->\n\n\n\n\t\t<!--TOGGLE SCRIPT WITH IMAGE-->\n\t\t(function ($){$(\'.reveal2\').hide();\n\t\t\t $(\'.toggle2\').click(function(){\n\t\t\t  \tvar t = $(this);\n\t\t\t  \tt.parent().find(\'.reveal2\').toggle("fast", function(){\n\t\t\t\t\t// determine which image to use if hidden div is hidden after the toggling is done\n\t\t\t\t\tvar imgsrc = ($(this).is(\':hidden\')) ? \'/sites/all/themes/WellesleyStandard/image/downarrow.png\' : \'/sites/all/themes/WellesleyStandard/image/uparrow.png\';\n\t\t\t\t\t// update image src\n\t\t\t\t\tt.attr(\'src\', imgsrc );\n\t\t\t  });\n\t\t })})(jQuery);\n\n\t   <!--END TOGGLE SCRIPT-->\n\n\n\t   <!--TOGGLE SCRIPT WITH DOTS-->\n\n\t\t(function ($){$(\'.reveal3\').hide();\n\t\t \t$(\'.toggle3\').click(function(){\n\t\t  \tvar t = $(this);\n\t\t  \tt.parent().find(\'.reveal3\').toggle("fast");\n\t\t   \tt.parent().find(\'.toggle3\').hide();\n\t\t })})(jQuery);\n\n\n\n\t   \t(function ($) {$(\'.toggleclose\').click(function () {\n\t\t  \tvar t = $(this);\n\t\t  \tt.parents().find(\'.reveal3\').toggle("fast");\n\t\t   \tt.parents(\'.toggle3\').show();\n\t\t});})(jQuery);\n\n\t   <!--END TOGGLE SCRIPT-->\n\n\n\n\n        ']
# []
# []
# ['About', 'Mission & Values', 'Robust Financial Aid', 'Wellesley Facts', 'Accreditation', 'Strategic Planning', 'President', 'The Wellesley Effect', 'The Campus', 'Sustainability', 'Wellesley in The World', 'College History', 'Wellesley Blogs', 'Visit', 'Admission & Financial Aid', 'Apply', 'Visit', 'Cost & Financial Aid', 'Diversity & Inclusion', 'Why Wellesley?', 'FAQ', 'Contact Us', 'Academics', 'The Academic Program', 'Library & Technology', 'Departments, Programs, & Majors', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs', 'Campus Life', 'Housing', 'Dining', 'Our Community', 'Health and Wellness', 'Getting to Boston', 'Student Life', 'Career Education', 'Athletics', 'Physical Education', 'Athletics', 'Recreation', 'Facilities & Hours', 'News', '2019 Stories', 'Wellesley in the News', 'Press Room', 'Daily Shot Gallery', 'News Archive', 'Events', 'The Arts at Wellesley', 'Wellesley on iTunes', 'Calendar', 'Event Planning', 'Commencement', 'Administration', 'Committees & Groups', 'Offices', 'Policies', 'Working at Wellesley', 'Alumnae', 'Alumnae in the News', 'Online Community', 'Classes, Clubs, & Groups', 'Events & Reunion', 'Wellesley Magazine', 'Awards', 'Volunteer', 'Life-Long Learning', 'Giving to Wellesley', 'About the Association']
# ['Mission & Values', 'Robust Financial Aid', 'Wellesley Facts', 'Accreditation', 'Strategic Planning', 'President', 'The Wellesley Effect', 'The Campus', 'Sustainability', 'Wellesley in The World', 'College History', 'Wellesley Blogs', 'Visit']
# ['Apply', 'Visit', 'Cost & Financial Aid', 'Diversity & Inclusion', 'Why Wellesley?', 'FAQ', 'Contact Us']
# ['The Academic Program', 'Library & Technology', 'Departments, Programs, & Majors', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['Housing', 'Dining', 'Our Community', 'Health and Wellness', 'Getting to Boston', 'Student Life', 'Career Education']
# ['Physical Education', 'Athletics', 'Recreation', 'Facilities & Hours']
# ['2019 Stories', 'Wellesley in the News', 'Press Room', 'Daily Shot Gallery', 'News Archive']
# ['The Arts at Wellesley', 'Wellesley on iTunes', 'Calendar', 'Event Planning', 'Commencement']
# ['Committees & Groups', 'Offices', 'Policies', 'Working at Wellesley']
# ['Alumnae in the News', 'Online Community', 'Classes, Clubs, & Groups', 'Events & Reunion', 'Wellesley Magazine', 'Awards', 'Volunteer', 'Life-Long Learning', 'Giving to Wellesley', 'About the Association']
# ['International study', '—approximately half of our students study abroad at some point during their time at Wellesley.', 'Research opportunities—our students work closely with professors on meaningful, challenging projects.', 'Interdisciplinary majors', '—students can select a number of majors that combine academic disciplines, or choose interdepartmental majors.', 'Internships', '—Wellesley supports a diverse variety of summer internships and community service projects around the world; many are eligible for financial support.', 'Programs with ', 'other colleges', '—students can enroll in cross-registration programs with Babson College, Brandeis University, MIT, and Olin College of Engineering, among other exchange programs with other colleges in the United States. Students can also apply to selective programs to earn a double degree with MIT or a combined five-year BA/MA in international economics and finance (BA/MAief) with Brandeis University.']
# ['Academics', 'The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['The Academic Program', 'Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar', 'Library & Technology', 'Departments, Majors & Programs', 'Course Catalog', 'WellesleyX', 'Faculty', 'Academic Centers', 'Academic Institutes', 'Academic Advising & Support', 'Registrar', 'Academic Summer Programs']
# ['Degree Requirements', 'International Study', 'Davis Degree Program', 'Opportunities at Other Schools', 'Postbaccalaureate', 'Calderwood Seminars in Public Writing', 'First Year Seminar']
# ['Provost & Dean of the College', 'The Humanities', 'Ruhlman Conference', 'Three College Collaboration', 'Health Professions Advising']
# ['Working at Wellesley', 'Giving to Wellesley', 'Directory', 'Terms of Use', 'Privacy', 'Key Facts', 'Web Accessibility', 'Feedback', 'Webmaster']
# ['The Academic Program | Wellesley College', ' HTML5 element support for IE6-8 ', '[if lt IE 9]>\n    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n  <![endif]', 'window.jQuery || document.write("<script src=\'/sites/all/modules/jquery_update/replace/jquery/1.7/jquery.min.js\'>\\x3C/script>")', '(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-6658128-21", {"cookieDomain":"auto"});ga(\'create\', \'UA-6658128-13\', \'auto\', {\'name\': \'newTracker\'});ga("set", "page", location.pathname + location.search + location.hash);ga("send", "pageview");ga(\'newTracker.send\', \'pageview\');', 'jQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"w_bootstrap_subtheme","theme_token":"BMP-QHxkZaRzrxeJm9iI_qs6ksHm8L0BC9f93B8zm6M","css":{"modules\\/system\\/system.base.css":1,"sites\\/all\\/modules\\/contrib\\/calendar\\/css\\/calendar_multiday.css":1,"sites\\/all\\/modules\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"sites\\/all\\/modules\\/date\\/date_repeat_field\\/date_repeat_field.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"sites\\/all\\/modules\\/video_filter\\/video_filter.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"sites\\/all\\/modules\\/thickbox\\/thickbox.css":1,"sites\\/all\\/modules\\/bootstrap_carousel\\/styles\\/bootstrap_carousel.css":1,"sites\\/all\\/libraries\\/fontawesome\\/css\\/font-awesome.css":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.0.2\\/css\\/bootstrap.min.css":1,"sites\\/all\\/themes\\/bootstrap\\/css\\/3.0.2\\/overrides.min.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/css\\/global_style.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/css\\/style.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/css\\/homepage.css":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/css\\/print.css":1},"js":{"sites\\/all\\/themes\\/bootstrap\\/js\\/bootstrap.js":1,"\\/\\/ajax.googleapis.com\\/ajax\\/libs\\/jquery\\/1.7.2\\/jquery.min.js":1,"0":1,"misc\\/jquery-extend-3.4.0.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.0.2\\/js\\/bootstrap.min.js":1,"sites\\/all\\/modules\\/thickbox\\/thickbox.js":1,"https:\\/\\/www.youtube.com\\/player_api":1,"sites\\/all\\/modules\\/bootstrap_carousel\\/scripts\\/bootstrap_carousel.js":1,"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js":1,"1":1,"sites\\/all\\/libraries\\/jquery.migrate\\/jquery-migrate-1.2.1.min.js":1,"sites\\/all\\/themes\\/bootstrap\\/js\\/main.js":1,"sites\\/all\\/themes\\/bootstrap\\/w_bootstrap_subtheme\\/..\\/..\\/..\\/libraries\\/masonry\\/jquery.masonry.min.js":1}},"thickbox":{"close":"Close","next":"Next \\u003E","prev":"\\u003C Prev","esc_key":"or Esc Key","next_close":"Next \\/ Close on last","image_count":"Image !current of !total"},"bootstrap_carousel":{"interval":"5000","pause":""},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackColorbox":1,"trackUrlFragments":1},"bootstrap":{"anchorsFix":1,"anchorsSmoothScrolling":1,"formHasError":1,"popoverEnabled":1,"popoverOptions":{"animation":1,"html":0,"placement":"right","selector":"","trigger":"click hover focus manual","triggerAutoclose":1,"title":"","content": ...

# %%
go_throug
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a3fb6ffb1326> in <module>
# ----> 1 go_throug
#
# NameError: name 'go_throug' is not defined

# %%
url='https://www.chess.com/home'

# %%
urlparse(url)
# Out:
# ParseResult(scheme='https', netloc='www.chess.com', path='/home', params='', query='', fragment='')
